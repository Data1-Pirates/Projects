# %%
import numpy as np
import pandas as pd
from sklearn import svm
import matplotlib as mptl
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.read_csv("New-Data.csv")
df
# Out:
#      Unnamed: 0  McCabe's line count of code  McCabe "cyclomatic complexity”  \
# 0             1                          1.0                             1.0
# 1             2                         24.0                             5.0
# 2             4                         24.0                             6.0
# 3             5                         24.0                             6.0
# 4             6                          7.0                             1.0
# ..          ...                          ...                             ...
# 390         493                         47.0                             3.0
# 391         494                         24.0                             4.0
# 392         495                         82.0                            11.0
# 393         496                         10.0                             2.0
# 394         497                         28.0                             6.0
#
#      McCabe "essential complexity”  McCabe "design complexity”  \
# 0                              1.0                         1.0
# 1                              1.0                         3.0
# 2                              6.0                         2.0
# 3                              6.0                         2.0
# 4                              1.0                         1.0
# ..                             ...                         ...
# 390                            1.0                         3.0
# 391                            3.0                         3.0
# 392                            3.0                        10.0
# 393                            1.0                         1.0
# 394                            5.0                         5.0
#
#      Halstead total operators + operands  Halstead "volume”  \
# 0                                    1.0               1.00
# 1                                   63.0             309.13
# 2                                   72.0             346.13
# 3                                   72.0             346.13
# 4                                   11.0              34.87
# ..                                   ...                ...
# 390                                256.0            1563.78
# 391                                107.0             587.63
# 392                                475.0            3155.83
# 393                                 32.0             150.41
# 394                                104.0             564.33
#
#      Halstead "program length”  Halstead "difficulty”  \
# 0                         1.00                   1.00
# 1                         0.11                   9.50
# 2                         0.06                  17.33
# 3                         0.06                  17.33
# 4                         0.50                   2.00
# ..                         ...                    ...
# 390                       0.04                  28.00
# 391                       0.05                  19.13
# 392                       0.02                  44.71
# 393                       0.15                   6.50
# 394                       0.06                  16.09
#
#      Halstead "intelligence”  ...  Halstead's line count  \
# 0                       1.00  ...                      1
# 1                      32.54  ...                      1
# 2                      19.97  ...                      0
# 3                      19.97  ...                      0
# 4                      17.43  ...                      0
# ..                       ...  ...                    ...
# 390                    55.85  ...                      2
# 391                    30.72  ...                      1
# 392                    70.59  ...                      9
# 393                    23.14  ...                      1
# 394                    35.08  ...                      2
#
#      Halstead's count of lines of comments  Halstead's count of blank  \
# 0                                        1                          1
# 1                                        0                          6
# 2                                        0                          3
# 3                                        0                          3
# 4                                        0                          1
# ..                                     ...                        ...
# 390                                     13                          2
# 391                                      7                          4
# 392                                     59                         35
# 393                                     12                          4
# 394                                      7                          0
#
#      lineslOCodeAndComment  unique operators  unique operands  \
# 0                        1               1.0              1.0
# 1                        0              15.0             15.0
# 2                        0              16.0             12.0
# 3                        0              16.0             12.0
# 4                        0               4.0              5.0
# ..                     ...               ...              ...
# 390                      0              23.0             46.0
# 391                      0              22.0             23.0
# 392                      0              32.0             68.0
# 393                      0              13.0             13.0
# 394                      0              20.0             23.0
#
#      total operators  total operands  branchCount of the flow graph  defects
# 0                1.0             1.0                            1.0        1
# 1               44.0            19.0                            9.0        0
# 2               46.0            26.0                           11.0        0
# 3               46.0            26.0                           11.0        0
# 4                6.0             5.0                            1.0        0
# ..               ...             ...                            ...      ...
# 390            144.0           112.0                            5.0        1
# 391             67.0            40.0                            7.0        1
# 392            285.0           190.0                           21.0        1
# 393             19.0            13.0                            3.0        1
# 394             67.0            37.0                           11.0        1
#
# [395 rows x 23 columns]

# %%
x = df.drop('defects', axis = 'columns')
y = df['defects']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y ,test_size = 0.2, random_state = 1)

# %%
a=GaussianNB()
a=a.fit(x_train,y_train)
y_pred=a.predict(x_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8734177215189873
